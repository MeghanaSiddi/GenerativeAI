# %% [markdown]
# ## Document

# %%
from langchain_core.documents import Document

# creating a document object

doc=Document(
    page_content="This is a sample doc",
    metadata={
        "source":"https://directai.blog/articles/docs/1.html",
        "author":"Meghana",
        "date":"10-07-2026"
    }
)

# %%
# using text loader

from langchain_community.document_loaders import TextLoader

text_loader=TextLoader(
    file_path="./data/intro.txt",
    autodetect_encoding=True
)
# Out:
# C:\Users\siddi\AppData\Local\Temp\ipykernel_23504\1985091198.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
documents=text_loader.load()

# %%
len(documents)
# Out:
# 1

# %%
print(documents[0].page_content)
# Out:
# # Introduction to HR Policies
#
# ## Welcome
#
# Welcome to our organization! We are committed to creating a professional, fair, safe, and respectful working environment for everyone. As a company that works with gig workers, freelancers, and independent contractors, we recognize the importance of flexibility while maintaining high standards of ethics, quality, and collaboration.
#
# Our Human Resources (HR) policies provide clear guidelines about how we work together, what you can expect from us, and what we expect from you. These policies are designed to ensure consistency, transparency, legal compliance, and mutual respect.
#
# Whether you are joining us for a short-term project or working with us regularly, these policies will help you understand your rights, responsibilities, and the standards of conduct expected while representing our organization.
#
# Our HR policies cover topics such as:
#
# * Code of Conduct
# * Equal Opportunity and Non-Discrimination
# ...

# %%
documents[0].metadata
# Out:
# {'source': './data/intro.txt'}

# %%
from langchain_community.document_loaders import PyPDFLoader

pdf_loader=PyPDFLoader(
    file_path="./data/sample.pdf"
)

# %%
docs=pdf_loader.load()

# %%
len(docs)
# Out:
# 13

# %%
from langchain_community.document_loaders import CSVLoader

csv_loader=CSVLoader(
    file_path="./data/sample.csv"
)

# %%
docs=csv_loader.load()

# %%
len(docs)
# Out:
# 50

# %%
dir_path="./data/text"

from langchain_community.document_loaders import DirectoryLoader,TextLoader

dir_loader=DirectoryLoader(
    path=dir_path,
    glob="*.txt",
    loader_cls=TextLoader)

docs=dir_loader.load()

# %%
len(docs)
# Out:
# 10

# %%
docs[0].page_content
# Out:
# '# Code of Conduct Policy\n\n## Purpose\nThis policy establishes the standards of professional behavior expected from all employees.\n\n## Standards of Conduct\n- Treat all colleagues, clients, and partners with respect and professionalism.\n- Maintain honesty and integrity in all business dealings.\n- Avoid conflicts of interest and disclose any potential conflicts to HR immediately.\n- Do not engage in any form of fraud, theft, or dishonest behavior.\n- Represent the company positively in all internal and external communications.\n\n## Use of Company Resources\n- Company resources (equipment, software, internet) must be used for business purposes only.\n- Personal use of company assets should be minimal and must not interfere with work duties.\n\n## Social Media\n- Employees must not post confidential company information on social media.\n- Public statements about the company must be approved by the communications team.\n\n## Violations\nViolations of this policy may result in disc
# ...

# %%
docs[0].metadata
# Out:
# {'source': 'data\\text\\01_code_of_conduct.txt'}

# %%
directory_loader=DirectoryLoader(
    path="./data/pdf",
    glob="**/*.pdf",
    loader_cls=PyPDFLoader
)

# %%
documents=directory_loader.load()

# %%
len(documents)
# Out:
# 60

# %%
documents[0].metadata
# Out:
# {'producer': 'ReportLab PDF Library - (opensource)',
#  'creator': '(unspecified)',
#  'creationdate': '2026-07-04T03:45:22+00:00',
#  'author': '(anonymous)',
#  'keywords': '',
#  'moddate': '2026-07-04T03:45:22+00:00',
#  'subject': '(unspecified)',
#  'title': '(anonymous)',
#  'trapped': '/False',
#  'source': 'data\\pdf\\01_Code_of_Conduct.pdf',
#  'total_pages': 6,
#  'page': 0,
#  'page_label': '1'}

# %%
documents[-1].metadata
# Out:
# {'producer': 'ReportLab PDF Library - (opensource)',
#  'creator': '(unspecified)',
#  'creationdate': '2026-07-04T03:45:22+00:00',
#  'author': '(anonymous)',
#  'keywords': '',
#  'moddate': '2026-07-04T03:45:22+00:00',
#  'subject': '(unspecified)',
#  'title': '(anonymous)',
#  'trapped': '/False',
#  'source': 'data\\pdf\\10_Learning_and_Development.pdf',
#  'total_pages': 6,
#  'page': 5,
#  'page_label': '6'}

# %%
from langchain_community.document_loaders import TextLoader

loader=TextLoader(
    file_path="./data/text/01_code_of_conduct.txt",
    encoding="utf-8"
)

documents=loader.load()

# %%
len(documents)
# Out:
# 1

# %%
documents[0].metadata
# Out:
# {'source': './data/text/01_code_of_conduct.txt'}

# %%
from langchain_text_splitters import CharacterTextSplitter

splitter=CharacterTextSplitter(
    chunk_size=87,
    chunk_overlap=16,
    separator=""
)

# %%
chunks=splitter.split_documents(documents)

# %%
len(chunks)
# Out:
# 15

# %%
chunks[0].metadata
# Out:
# {'source': './data/text/01_code_of_conduct.txt'}

# %%
print(chunks[0].page_content)
# Out:
# # Code of Conduct Policy
#
# ## Purpose
# This policy establishes the standards of professio

# %%
print(chunks[1].page_content)
# Out:
# rds of professional behavior expected from all employees.
#
# ## Standards of Conduct
# - Tr

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter=RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=15,
    separators=["\n\n","\n"," ",""]
)

chunks=splitter.split_documents(documents)

# %%
len(chunks)
# Out:
# 16

# %%
print(chunks[0].page_content)
# Out:
# # Code of Conduct Policy

# %%
print(chunks[1].page_content)
# Out:
# ## Purpose

# %%
story="""Once upon a time, a quiet clockmaker named Thomas lived in a small valley surrounded by foggy hills. He spent his days in a dusty shop, surrounded by ticking clocks of all shapes and sizes. Every gear he turned and every spring he wound brought him peace. The townspeople brought him their broken timepieces, knowing his hands could fix anything. Yet, Thomas always felt he was waiting for something unusual to happen.

One chilly evening, a cloaked traveler entered his shop carrying a heavy wooden box. The stranger placed it on the counter, whispered that it could not be fixed by ordinary means, and vanished into the mist. Inside the box lay a strange brass device with glowing runes instead of numbers. It did not tick; it hummed with a low, vibrating energy that filled the room. Thomas felt a thrill of excitement he had not experienced in years.

He stayed up all night examining the mysterious mechanism under his magnifying glass. As his brass tools touched the main gear, the room fell completely silent, and the ticking of his other clocks stopped. The air grew warm, and the glowing runes began to spin backwards at high speed. Outside his window, the falling rain froze mid-air, suspended like tiny diamonds in the dark night. He had accidentally paused time itself.

Realizing the immense power in his hands, Thomas carefully turned the gear back to its original position. The clocks immediately resumed their ticking, and the rain splashed loudly against the glass. He knew this device was too dangerous to be left unattended or forgotten. He closed his shop, packed his tools into a leather bag, and set off into the foggy hills to find the traveler and uncover the truth.
"""

# %%
chunks=splitter.split_text(
    story
)

# %%
len(chunks)
# Out:
# 21

# %%
print(chunks[0])
# Out:
# Once upon a time, a quiet clockmaker named Thomas lived in a small valley surrounded by foggy hills.

# %%
for chunk in chunks:
    print(chunk)
# Out:
# Once upon a time, a quiet clockmaker named Thomas lived in a small valley surrounded by foggy hills.
# foggy hills. He spent his days in a dusty shop, surrounded by ticking clocks of all shapes and
# all shapes and sizes. Every gear he turned and every spring he wound brought him peace. The
# him peace. The townspeople brought him their broken timepieces, knowing his hands could fix
# could fix anything. Yet, Thomas always felt he was waiting for something unusual to happen.
# One chilly evening, a cloaked traveler entered his shop carrying a heavy wooden box. The stranger
# The stranger placed it on the counter, whispered that it could not be fixed by ordinary means, and
# means, and vanished into the mist. Inside the box lay a strange brass device with glowing runes
# glowing runes instead of numbers. It did not tick; it hummed with a low, vibrating energy that
# energy that filled the room. Thomas felt a thrill of excitement he had not experienced in years.
# ...

# %%
splitter=RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100    
)
chunks=splitter.split_text(
    story
)

# %%
len(chunks)
# Out:
# 4

# %%
for chunk in chunks:
    print(chunk)
# Out:
# Once upon a time, a quiet clockmaker named Thomas lived in a small valley surrounded by foggy hills. He spent his days in a dusty shop, surrounded by ticking clocks of all shapes and sizes. Every gear he turned and every spring he wound brought him peace. The townspeople brought him their broken timepieces, knowing his hands could fix anything. Yet, Thomas always felt he was waiting for something unusual to happen.
# One chilly evening, a cloaked traveler entered his shop carrying a heavy wooden box. The stranger placed it on the counter, whispered that it could not be fixed by ordinary means, and vanished into the mist. Inside the box lay a strange brass device with glowing runes instead of numbers. It did not tick; it hummed with a low, vibrating energy that filled the room. Thomas felt a thrill of excitement he had not experienced in years.
# ...

# %%
splitter=RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100,
    separators=["."]

)
chunks=splitter.split_text(
    story
)

# %%
len(chunks)
# Out:
# 5

# %%
for chunk in chunks:
    print(chunk)
# Out:
# Once upon a time, a quiet clockmaker named Thomas lived in a small valley surrounded by foggy hills. He spent his days in a dusty shop, surrounded by ticking clocks of all shapes and sizes. Every gear he turned and every spring he wound brought him peace. The townspeople brought him their broken timepieces, knowing his hands could fix anything. Yet, Thomas always felt he was waiting for something unusual to happen
# . Yet, Thomas always felt he was waiting for something unusual to happen.
#
# One chilly evening, a cloaked traveler entered his shop carrying a heavy wooden box. The stranger placed it on the counter, whispered that it could not be fixed by ordinary means, and vanished into the mist. Inside the box lay a strange brass device with glowing runes instead of numbers. It did not tick; it hummed with a low, vibrating energy that filled the room
# ...

# %%
from langchain_text_splitters.markdown import MarkdownHeaderTextSplitter

md_doc=TextLoader(
    file_path="./data/story.md",
    encoding="utf-8"
)

splitter=MarkdownHeaderTextSplitter(
    headers_to_split_on=[
        ("#","Header 1"),
        ("##","Header 2"),
        ("###","Header 3")
    ]
)

# %%
chunks=splitter.split_text(
    md_doc.load()[0].page_content
)

# %%
len(chunks)
# Out:
# 4

# %%
print(chunks[0].page_content)
# Out:
# Once upon a time, a quiet clockmaker named **Thomas** lived in a small valley surrounded by foggy hills.
# He spent his days in a dusty shop, surrounded by ticking clocks of all shapes and sizes. Every gear he turned and every spring he wound brought him peace.
# The townspeople brought him their broken timepieces, knowing his skilled hands could fix almost anything. Yet, despite his peaceful life, Thomas often felt as though he was waiting for something extraordinary to happen.
# ---

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

loader=TextLoader(
    file_path="./data/story.txt",
    autodetect_encoding=True
)

splitter=RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=20
)

#chunks
documents=loader.load_and_split(splitter)

# %%
len(documents)
# Out:
# 23

# %%
for document in documents:
    print(document.page_content)
    print(document.metadata)
# Out:
# Once upon a time, a quiet clockmaker named Thomas lived in a small valley surrounded by foggy hills.
# {'source': './data/story.txt'}
# by foggy hills. He spent his days in a dusty shop, surrounded by ticking clocks of all shapes and
# {'source': './data/story.txt'}
# of all shapes and sizes. Every gear he turned and every spring he wound brought him peace. The
# {'source': './data/story.txt'}
# him peace. The townspeople brought him their broken timepieces, knowing his hands could fix
# {'source': './data/story.txt'}
# his hands could fix anything. Yet, Thomas always felt he was waiting for something unusual to
# {'source': './data/story.txt'}
# unusual to happen.
# {'source': './data/story.txt'}
# One chilly evening, a cloaked traveler entered his shop carrying a heavy wooden box. The stranger
# {'source': './data/story.txt'}
# box. The stranger placed it on the counter, whispered that it could not be fixed by ordinary means,
# {'source': './data/story.txt'}
# ...

# %%
from langchain_community.document_loaders.directory import DirectoryLoader

dir_path="./data/exercise/data"
dir_loader=DirectoryLoader(
    path=dir_path,
    glob="*.txt",
    loader_cls=TextLoader)

docs=dir_loader.load()

# %%
len(docs)

for doc in docs:
    print(doc.page_content)
    print(doc.metadata)
# Out:
# Apples grow on trees and are enjoyed around the world. They can be eaten fresh, baked into desserts, or pressed into juice.
# {'source': 'data\\exercise\\data\\file1.txt'}
# Teamwork often leads to better results than working alone. Sharing ideas and supporting one another improves success.
# {'source': 'data\\exercise\\data\\file10.txt'}
# The sun rises in the east and sets in the west. Its light and heat make life on Earth possible.
# {'source': 'data\\exercise\\data\\file2.txt'}
# Reading books is a wonderful habit. It improves vocabulary, expands knowledge, and stimulates imagination.
# {'source': 'data\\exercise\\data\\file3.txt'}
# Exercise helps keep the body healthy and the mind active. Even a short daily walk can make a difference.
# {'source': 'data\\exercise\\data\\file4.txt'}
# Rivers carry fresh water from mountains to oceans. They support wildlife and provide water for communities.
# {'source': 'data\\exercise\\data\\file5.txt'}
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter=RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=15,
    separators=["\n\n","\n"," ",".",""]
)

chunks=splitter.split_documents(docs)

# %%
len(chunks)
# Out:
# 18

# %%
from datetime import datetime

for chunk in chunks:    
    chunk.metadata["project"]="learning"
    chunk.metadata["ingested_date"]=datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    print(chunk.page_content)
    print(chunk.metadata)
# Out:
# Apples grow on trees and are enjoyed around the world. They can be eaten fresh, baked into desserts,
# {'source': 'data\\exercise\\data\\file1.txt', 'project': 'learning', 'ingested_date': '2026-07-27 21:46:11'}
# into desserts, or pressed into juice.
# {'source': 'data\\exercise\\data\\file1.txt', 'project': 'learning', 'ingested_date': '2026-07-27 21:46:11'}
# Teamwork often leads to better results than working alone. Sharing ideas and supporting one another
# {'source': 'data\\exercise\\data\\file10.txt', 'project': 'learning', 'ingested_date': '2026-07-27 21:46:11'}
# one another improves success.
# {'source': 'data\\exercise\\data\\file10.txt', 'project': 'learning', 'ingested_date': '2026-07-27 21:46:11'}
# The sun rises in the east and sets in the west. Its light and heat make life on Earth possible.
# {'source': 'data\\exercise\\data\\file2.txt', 'project': 'learning', 'ingested_date': '2026-07-27 21:46:11'}
# ...

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embedding = GoogleGenerativeAIEmbeddings(
    model="text-embedding-005"
)

# %%
result=embedding.embed_query("what is Refund?")

# %%
print(result)
# Out:
# [0.018008291721343994, -0.04309044033288956, -0.0021772088948637247, -0.009129193611443043, 0.058084603399038315, 0.02055978961288929, 0.01774042285978794, 0.04974230378866196, 0.0379084050655365, -0.0006936669815331697, -0.0016546184197068214, -0.0788201168179512, 0.023977914825081825, -0.00027679791674017906, 0.01038492750376463, 0.02521336078643799, 0.01128135621547699, -0.0713302344083786, 0.011834688484668732, 0.009998485445976257, -0.012845908291637897, -0.020992863923311234, -0.06704763323068619, -0.002619090024381876, -0.0681532472372055, -0.019824421033263206, -0.022244978696107864, 0.0807240903377533, -0.04017116501927376, 0.02692783996462822, 0.007650766987353563, -0.037827637046575546, 0.059864889830350876, 0.06373249739408493, -0.02073347568511963, -0.02380450814962387, 0.07006365805864334, 0.021813007071614265, -0.040242791175842285, 0.015195097774267197, 0.020203454419970512, 0.0007449286640621722, -0.01646512933075428, 0.011343767866492271, -0.018124449998140335, 0.02
# ...

# %%
len(result)
# Out:
# 768

# %%
# First 10 co-ordinates
result[:10]
# Out:
# [0.018008291721343994,
#  -0.04309044033288956,
#  -0.0021772088948637247,
#  -0.009129193611443043,
#  0.058084603399038315,
#  0.02055978961288929,
#  0.01774042285978794,
#  0.04974230378866196,
#  0.0379084050655365,
#  -0.0006936669815331697]

# %%
embedding=GoogleGenerativeAIEmbeddings(
    model="gemini-embedding-001"
)

result=embedding.embed_query("What is Refund?")

# %%
len(result)
# Out:
# 3072

# %%
from langchain_core.documents import Document
documents=[
     Document(
        page_content="Refund is a process where money is returned to a customer.",
        metadata={"source": "https://example.com/refund"}
    ),
    Document(
        page_content="A refund request must be submitted within 30 days of purchase.",
        metadata={"source": "https://example.com/refund-policy"}
    ),
    Document(
        page_content="Refunds are processed within 5-7 business days after approval.",
        metadata={"source": "https://example.com/processing-time"}
    )
]

texts=[doc.page_content for doc in documents]

#chunks 
embeddings=embedding.embed_documents(texts)

print(len(embeddings))
print(len(embeddings[0]))
# Out:
# 3
# 3072

# %%
from langchain_chroma import Chroma

hello_vs=Chroma(
    collection_name="firstvs",
    embedding_function=embedding,
    persist_directory="./vectorstores/hello"
)

# %%
hello_vs.add_documents(documents=documents)
# Out:
# ['ae130190-bfd7-4ab9-9f23-1e1b16fa97ab',
#  '2e2d2b3d-99c8-4818-9a6d-98be080ab1cf',
#  '29fee83d-7cd0-4782-8f69-449dac77bda4']

# %%
results=hello_vs.as_retriever().invoke("money")

# %%
for result in results:
    print(result)
# Out:
# page_content='Refund is a process where money is returned to a customer.' metadata={'source': 'https://example.com/refund'}
# page_content='Refunds are processed within 5-7 business days after approval.' metadata={'source': 'https://example.com/processing-time'}
# page_content='A refund request must be submitted within 30 days of purchase.' metadata={'source': 'https://example.com/refund-policy'}

# %%
from langchain_community.document_loaders.directory import DirectoryLoader

dir_path="./data/excercise1/data"
dir_loader=DirectoryLoader(
    path=dir_path,
    glob="*.txt",
    loader_cls=TextLoader)

docs=dir_loader.load()

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter=RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=15,
    separators=["\n\n","\n"," ",".",""]
)

#chunks
chunks=splitter.split_documents(docs)
print(chunks)
# Out:
# [Document(metadata={'source': 'data\\excercise1\\data\\Ahmedabad.txt'}, page_content='Ahmedabad is the largest city in Gujarat and an important industrial center. It is associated with'), Document(metadata={'source': 'data\\excercise1\\data\\Ahmedabad.txt'}, page_content='with Mahatma Gandhi through the Sabarmati Ashram.'), Document(metadata={'source': 'data\\excercise1\\data\\Ahmedabad.txt'}, page_content='The city has modern infrastructure, heritage sites, and a growing economy. Textile manufacturing'), Document(metadata={'source': 'data\\excercise1\\data\\Ahmedabad.txt'}, page_content='manufacturing and entrepreneurship are major strengths.'), Document(metadata={'source': 'data\\excercise1\\data\\Bengaluru.txt'}, page_content='Bengaluru is known as the Silicon Valley of India because of its thriving technology industry. Many'), Document(metadata={'source': 'data\\excercise1\\data\\Bengaluru.txt'}, page_content='industry. Many startups and multinational companies have offices here.
# ...

# %%
print((chunks[0].metadata["source"]))
# Out:
# data\excercise1\data\Ahmedabad.txt

# %%
len(chunks)
# Out:
# 41

# %%
from pathlib import Path

for i,chunk in enumerate(chunks,start=1):    
    chunk.metadata["city"]=Path(chunk.metadata["source"]).stem
    chunk.metadata["chunk-id"]=i
    print(chunk.page_content)
    print(chunk.metadata)
# Out:
# Ahmedabad is the largest city in Gujarat and an important industrial center. It is associated with
# {'source': 'data\\excercise1\\data\\Ahmedabad.txt', 'city': 'Ahmedabad', 'chunk-id': 1}
# with Mahatma Gandhi through the Sabarmati Ashram.
# {'source': 'data\\excercise1\\data\\Ahmedabad.txt', 'city': 'Ahmedabad', 'chunk-id': 2}
# The city has modern infrastructure, heritage sites, and a growing economy. Textile manufacturing
# {'source': 'data\\excercise1\\data\\Ahmedabad.txt', 'city': 'Ahmedabad', 'chunk-id': 3}
# manufacturing and entrepreneurship are major strengths.
# {'source': 'data\\excercise1\\data\\Ahmedabad.txt', 'city': 'Ahmedabad', 'chunk-id': 4}
# Bengaluru is known as the Silicon Valley of India because of its thriving technology industry. Many
# {'source': 'data\\excercise1\\data\\Bengaluru.txt', 'city': 'Bengaluru', 'chunk-id': 5}
# industry. Many startups and multinational companies have offices here.
# ...

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embedding=GoogleGenerativeAIEmbeddings(
    model="text-embedding-005"
)

texts=[chunk.page_content for chunk in chunks]

#vectors or embeddings
vectors=embedding.embed_documents(texts)

# %%
print(vectors)
len(vectors)
# Out:
# [[-0.044677168130874634, -0.0171328354626894, 0.022551164031028748, -0.028996940702199936, -0.05292103439569473, 0.06396713852882385, -0.022148050367832184, -0.0031930250115692616, -0.017848925665020943, 0.0011357702314853668, -0.0353924036026001, -0.07908971607685089, 0.007303622551262379, -0.011706420220434666, -0.058227866888046265, 0.04904927313327789, 0.026852654293179512, -0.025470398366451263, 0.020293451845645905, -0.02526240423321724, -0.0027635800652205944, -0.08623559027910233, -0.048558320850133896, -0.03732636198401451, 0.09858003258705139, 0.022059226408600807, -0.044870879501104355, -0.01162893045693636, -0.02583899348974228, -0.00580945611000061, 0.08190751075744629, -0.023546673357486725, 0.0047858585603535175, 0.0006815805681981146, -0.03881560638546944, -0.01804974116384983, 0.022360099479556084, -0.00839058868587017, 0.14046676456928253, 0.013810964301228523, 0.021437576040625572, -0.04623892530798912, -0.011695809662342072, -0.043496496975421906, 0.02096100151538
# ...

# %%
from langchain_chroma import Chroma

example1_vs=Chroma(
    collection_name="city_vs",
    embedding_function=embedding,
    persist_directory="./vectorstores/example1"
)

example1_vs.add_documents(documents=chunks)
# Out:
# ['32a124f4-7fe6-4b58-b250-316d7e5a5b69',
#  '9860c73c-d0f3-4cb1-9aa5-0fbd5d48d4e8',
#  '24bc2f76-e3aa-400b-b0f2-518a716ccf4e',
#  'c02bfa2a-22fa-46a2-8111-34e7f3a459a4',
#  '08e2c065-a895-4dde-8e2d-a43d2b7ece04',
#  '3df64508-79fe-4a67-b535-0211bd5756f7',
#  '8a976d90-b578-4fb0-9c2e-bccb573b9e0a',
#  'a15dabaf-7c5e-4d73-b81e-65f63e960120',
#  'dd3d8c0d-f6c9-4beb-a855-5ff7a2df40e8',
#  '06ed279d-32db-4c8d-92d9-6fa52cde3516',
#  '75cb4799-2f7c-4968-9d5f-ca1d2df37b1b',
#  'eb0e2bca-390c-402c-9c79-1bf366b30804',
#  '8625481d-7147-4f5c-8b7e-63c60289a14a',
#  '95aab774-3465-43d1-9c2f-c62797e49cd9',
#  'b54afacd-0424-46e2-8784-6cce2ab19aff',
#  '98562981-518e-4d3b-960d-7373d6eac541',
#  'c28e5f15-9920-4bee-bb13-17d004fd62e2',
#  'f4eb6568-da3e-49c4-b6f7-ef384e041753',
#  '7a38e15e-ed63-43af-9ce1-4742055dfdcb',
#  '7f5ad9fe-587c-43fa-bf2b-1cf310a46fd0',
#  '70aed317-51bc-4a2a-921e-e5f28cb011ee',
#  '6679f63f-dce9-43ad-8f12-3278c800ad43',
#  '7870bc7f-8322-470b-a97f-d875a5189527',
# ...

# %%
#Using Retreiever

results=example1_vs.as_retriever(
    search_kwargs={"k": 2}
).invoke("Tell me about Hyderabad? And give it's chunk id?")

for result in results:
    print(result.page_content)
    print(result.metadata["city"])
    print(result.metadata["chunk-id"])
    print("-"*20)
# Out:
# The city combines historical landmarks with modern business districts like HITEC City. Hyderabad is
# Hyderabad
# 20
# --------------------
# Hyderabad is famous for its rich history, Charminar, and delicious biryani. It has grown into a
# Hyderabad
# 18
# --------------------
